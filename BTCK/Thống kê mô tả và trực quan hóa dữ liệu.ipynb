# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Data-Stata3.xlsx")

# %%
print(" 5 dòng đầu tiên:")
print(data.head())
# Out:
#  5 dòng đầu tiên:
#    Tỉnh/Thành  2019  2020  2021  2022    2023
# 0      Hà Nội  2410  2454  2480  2511  2555.8
# 1   Vĩnh Phúc   934   948   964   969   980.1
# 2    Bắc Ninh  1676  1725  1778  1809  1844.4
# 3  Quảng Ninh   214   216   218   220   222.5
# 4   Hải Dương  1137  1149  1161  1167  1173.0

# %%
data = data.rename(columns={"Unnamed: 0": "Tỉnh/Thành"})

# %%
print("Thống kê mô tả (Descriptive Statistics):")
desc = data.describe()
print(desc)
# Out:
# Thống kê mô tả (Descriptive Statistics):
#               2019         2020         2021         2022        2023
# count    64.000000    64.000000    64.000000    64.000000    64.00000
# mean    508.093750   513.468750   518.218750   523.953125   528.48125
# std     667.458642   674.605304   675.996371   689.514470   696.63019
# min      51.000000    52.000000    53.000000    53.000000    54.00000
# 25%     136.250000   135.750000   137.750000   137.750000   139.00000
# 50%     258.500000   258.500000   262.500000   262.000000   262.30000
# 75%     604.000000   609.250000   613.250000   614.750000   617.95000
# max    4385.000000  4404.000000  4375.000000  4481.000000  4513.10000

# %%
print(" Ma trận tương quan:")
corr = data.drop(columns=["Tỉnh/Thành"]).corr()
print(corr)
# Out:
#  Ma trận tương quan:
#           2019      2020      2021      2022      2023
# 2019  1.000000  0.999906  0.999693  0.999627  0.999445
# 2020  0.999906  1.000000  0.999898  0.999865  0.999759
# 2021  0.999693  0.999898  1.000000  0.999918  0.999872
# 2022  0.999627  0.999865  0.999918  1.000000  0.999975
# 2023  0.999445  0.999759  0.999872  0.999975  1.000000

# %% [markdown]
# # Histogram

# %%
df.hist(figsize=(12, 8), bins=15, edgecolor='black')
plt.suptitle("Phân phối của các biến qua từng năm", fontsize=16)
plt.show()

# %% [markdown]
# # Boxplot

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=data.drop(columns=["Tỉnh/Thành"]))
plt.title("Biểu đồ Boxplot các năm")
plt.show()

# %% [markdown]
# # Scatterplot

# %%
plt.figure(figsize=(6, 5))
sns.scatterplot(x=data["2019"], y=data["2023"])
plt.title("Quan hệ giữa biến năm 2019 và 2023")
plt.xlabel("Năm 2019")
plt.ylabel("Năm 2023")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Heatmap - Ma Trận tương quan giữa các chỉ số nghèo đa chiều")
plt.show()
